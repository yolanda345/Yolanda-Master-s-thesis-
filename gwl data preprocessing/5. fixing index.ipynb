# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib as plt
from datetime import date
from datetime import datetime
import glob

# %%
#testing glob 
l = glob.glob('/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/*.xlsx')
l
# Out:
# ['/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ D4N0124.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ D4N0108.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ 2525DD00027.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ D4N0094.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ 2525DD00046.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ D4N0112.xlsx',
#  '/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/ D4N0693.xlsx',
# ...

# %%
import glob, os

for file in glob.glob('/Users/yolanda/Documents/Priority compartments/Grootfontein/gwls/Final individual boreholes/untitled folder/*.xlsx'):

    df = pd.read_excel(file, index_col=[0]).set_index('year_month')
    print (df)

    #new excel files

    h,t = os.path.split(file)
    df.to_excel(os.path.join(h, 'new_' + t))
# Out:
#              D4N0124
# year_month
# 1977-06-01     19.88
# 1977-07-01       NaN
# 1977-08-01       NaN
# 1977-09-01       NaN
# 1977-10-01       NaN
# ...              ...
# 2004-04-01     31.02
# 2004-05-01       NaN
# 2004-06-01     31.04
# 2004-07-01       NaN
# 2004-08-01     31.07
#
# [327 rows x 1 columns]
#              D4N0108
# year_month
# 1975-07-01     12.35
# 1975-08-01     12.37
# 1975-09-01     12.46
# 1975-10-01     12.60
# 1975-11-01     12.61
# ...              ...
# 2019-02-01     12.73
# 2019-03-01       NaN
# 2019-04-01       NaN
# 2019-05-01       NaN
# 2019-06-01     14.42
#
# [528 rows x 1 columns]
#              2525DD00027
# year_month
# 1975-05-01         11.34
# 1975-06-01         11.00
# 1975-07-01         11.17
# 1975-08-01           NaN
# 1975-09-01         12.68
# ...                  ...
# 1985-03-01         26.51
# 1985-04-01         26.53
# 1985-05-01         26.55
# 1985-06-01         26.57
# 1985-07-01         26.57
#
# [123 rows x 1 columns]
# ...
